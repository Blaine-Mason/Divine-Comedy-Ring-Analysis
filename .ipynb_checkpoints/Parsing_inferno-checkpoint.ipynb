# %%
import numpy as np
import pandas as pd


def unique_list(l):
    ulist = []
    [ulist.append(x) for x in l if x not in ulist]
    return ulist

df = pd.read_table('inferno.txt',header=None)
line_nums = list(df[0].str.extractall(r"(Inferno . Canto .{1,6})")[0].index)
for i in range(0,len(line_nums)):
    line_nums[i] = line_nums[i][0]
line_nums.append(len(df))

inferno = pd.DataFrame(index=[f"Canto-{x}" for x in range(1,35)], columns=["Lines"])
cantos = [f"Canto-{x}" for x in range(1,35)]

i = 1
for c in cantos:
    inferno.at[c, "Lines"] = list(df[0][line_nums[i-1]+1:line_nums[i]])
    i = i + 1

# %%
inferno
# Out:
#                                                       Lines
# Canto-1   [Nel mezzo del cammin di nostra vita, mi ritro...
# Canto-2   [Lo giorno se n’andava, e l’aere bruno, toglie...
# Canto-3   [“Per me si va ne la città dolente,, per me si...
# Canto-4   [Ruppemi l’alto sonno ne la testa, un greve tr...
# Canto-5   [Così discesi del cerchio primaio, giù nel sec...
# Canto-6   [Al tornar de la mente, che si chiuse, dinanzi...
# Canto-7   [«Pape Satàn, pape Satàn aleppe!»,, cominciò P...
# Canto-8   [Io dico, seguitando, ch’assai prima, che noi ...
# Canto-9   [Quel color che viltà di fuor mi pinse, veggen...
# Canto-10  [Ora sen va per un secreto calle,, tra ’l muro...
# Canto-11  [In su l’estremità d’un’alta ripa, che facevan...
# Canto-12  [Era lo loco ov’ a scender la riva, venimmo, a...
# Canto-13  [Non era ancor di là Nesso arrivato,, quando n...
# Canto-14  [Poi che la carità del natio loco, mi strinse,...
# Canto-15  [Ora cen porta l’un de’ duri margini;, e ’l fu...
# Canto-16  [Già era in loco onde s’udia ’l rimbombo, de l...
# Canto-17  [«Ecco la fiera con la coda aguzza,, che passa...
# Canto-18  [Luogo è in inferno detto Malebolge,, tutto di...
# Canto-19  [O Simon mago, o miseri seguaci, che le cose d...
# Canto-20  [Di nova pena mi conven far versi, e dar mater...
# Canto-21  [Così di ponte in ponte, altro parlando, che l...
# Canto-22  [Io vidi già cavalier muover campo,, e cominci...
# Canto-23  [Taciti, soli, sanza compagnia, n’andavam l’un...
# Canto-24  [In quella parte del giovanetto anno, che ’l s...
# Canto-25  [Al fine de le sue parole il ladro, le mani al...
# Canto-26  [Godi, Fiorenza, poi che se’ sì grande, che pe...
# Canto-27  [Già era dritta in sù la fiamma e queta, per n...
# Canto-28  [Chi poria mai pur con parole sciolte, dicer d...
# Canto-29  [La molta gente e le diverse piaghe, avean le ...
# Canto-30  [Nel tempo che Iunone era crucciata, per Semel...
# Canto-31  [Una medesma lingua pria mi morse,, sì che mi ...
# Canto-32  [S’ïo avessi le rime aspre e chiocce,, come si...
# Canto-33  [La bocca sollevò dal fiero pasto, quel peccat...
# Canto-34  [«Vexilla regis prodeunt inferni, verso di noi...

# %%
# i = 1
# for c in cantos:
#     canto = " ".join(inferno.loc[c]["Lines"])
#     inferno.at[c, "Lines"] = ' '.join(unique_list(canto.split()))
#     i = i + 1

# %%
from feel_it import EmotionClassifier, SentimentClassifier

emotion_classifier = EmotionClassifier()

emotion_classifier.predict(["sono molto felice", "ma che cazzo vuoi", "sono molto triste"])
